# %% [markdown]
# # Lets inspect and play around with MIDI data

# %%
from miditoolkit import MidiFile
import os
DATA_DIR = "/Users/juanigp/Desktop/data"

# %%
midi_file = "e-gmd-v1.0.0/drummer1/session1/2_funk_80_beat_4-4_5.midi"
midi_file_dir = os.path.join(DATA_DIR, midi_file)
midi = MidiFile(midi_file_dir)
midi
# Out:
# ticks per beat: 480
# max tick: 55682
# tempo changes: 1
# time sig: 1
# key sig: 1
# markers: 0
# lyrics: False
# instruments: 1

# %%
from miditok import REMI

tokenizer = REMI()
tokens = tokenizer.midi_to_tokens(midi)
tokens
# Out:
# [[1,
#   208,
#   19,
#   95,
#   122,
#   209,
#   19,
#   97,
#   122,
#   210,
#   19,
#   102,
#   122,
#   212,
#   19,
#   101,
#   122,
#   214,
#   19,
#   104,
#   122,
#   216,
#   19,
#   98,
#   122,
#   1,
#   186,
#   17,
#   99,
#   122,
#   23,
#   98,
#   122,
#   188,
#   23,
#   95,
#   122,
#   190,
#   17,
#   99,
#   122,
#   23,
#   99,
#   122,
#   192,
#   23,
#   95,
#   122,
#   194,
#   18,
#   106,
#   122,
#   23,
#   97,
#   122,
#   196,
#   17,
#   97,
#   122,
#   27,
#   94,
#   122,
#   197,
#   25,
#   106,
#   122,
#   198,
#   23,
#   97,
#   122,
#   200,
#   19,
#   100,
#   122,
#   23,
#   98,
#   122,
#   202,
#   23,
#   98,
#   122,
#   204,
#   19,
#   94,
#   122,
#   23,
#   96,
#   122,
#   206,
#   17,
#   98,
#   122,
#   23,
#   99,
#   122,
#   208,
#   23,
#   96,
#   122,
#   210,
#   19,
#   102,
#   122,
#   23,
#   97,
#   122,
#   212,
#   17,
#   99,
#   122,
#   23,
#   96,
#   122,
#   214,
#   23,
#   100,
#   122,
# ...

# %%
len(tokenizer.vocab)
# Out:
# 218
